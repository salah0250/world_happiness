# %% [markdown]
# # Analysis Data :

# %% [markdown]
# - explore and discribe data
# - merge data from 2015-2019
# - clean data (replace NaN values and delete redudant variables)

# %%
import pandas as pd 

import matplotlib.pyplot as plt
#import datasets 
happy15_df = pd.read_csv ("all_data/2015.csv")
happy16_df = pd.read_csv ("all_data/2016.csv")
happy17_df = pd.read_csv ("all_data/2017.csv")
happy18_df = pd.read_csv ("all_data/2018.csv")
happy19_df = pd.read_csv ("all_data/2019.csv")

happy19_df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# 3                      0.118
# 4                      0.298

# %% [markdown]
# # inspect datasets

# %%
print (" Shape15:" , happy15_df.shape ,"\n",
       "Shape16:" , happy16_df.shape ,"\n",
       "Shape17:" , happy17_df.shape ,"\n",
       "Shape18:" , happy18_df.shape ,"\n",
       "Shape19:" , happy19_df.shape  )
# Out:
#  Shape15: (158, 12)
#  Shape16: (157, 13)
#  Shape17: (155, 12)
#  Shape18: (156, 9)
#  Shape19: (156, 9)

# %%
#values and data types of the 5 datasets 
print ( happy15_df.info() 
       , happy16_df.info() 
       , happy17_df.info()
       , happy18_df.info() 
       , happy19_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        157 non-null    object
#  1   Region                         157 non-null    object
#  2   Happiness Rank                 157 non-null    int64
#  3   Happiness Score                157 non-null    float64
#  4   Lower Confidence Interval      157 non-null    float64
#  5   Upper Confidence Interval      157 non-null    float64
#  6   Economy (GDP per Capita)       157 non-null    float64
#  7   Family                         157 non-null    float64
#  8   Health (Life Expectancy)       157 non-null    float64
#  9   Freedom                        157 non-null    float64
#  10  Trust (Government Corruption)  157 non-null    float64
#  11  Generosity                     157 non-null    float64
#  12  Dystopia Residual              157 non-null    float64
# dtypes: float64(10), int64(1), object(2)
# memory usage: 16.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        155 non-null    object
#  1   Happiness.Rank                 155 non-null    int64
#  2   Happiness.Score                155 non-null    float64
#  3   Whisker.high                   155 non-null    float64
#  4   Whisker.low                    155 non-null    float64
#  5   Economy..GDP.per.Capita.       155 non-null    float64
#  6   Family                         155 non-null    float64
#  7   Health..Life.Expectancy.       155 non-null    float64
#  8   Freedom                        155 non-null    float64
#  9   Generosity                     155 non-null    float64
#  10  Trust..Government.Corruption.  155 non-null    float64
#  11  Dystopia.Residual              155 non-null    float64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 14.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     155 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB
# None None None None None

# %%
"""
renaming of year 2018 and 2019 
labeling as the base: 2015
will create new colums as soon as we merge the data
"""

#Country 

happy18_df = happy18_df.rename(columns= {"Country or region": "Country"})

happy18_df

happy19_df = happy18_df.rename(columns= {"Country or region": "Country"})

happy19_df


#Happiness Rank 

happy18_df = happy18_df.rename(columns= {"Overall rank": "Happiness Rank"})

happy18_df

happy19_df = happy18_df.rename(columns= {"Overall rank": "Happiness Rank"})

happy19_df



#Economy (GDP per Capita)

happy18_df = happy18_df.rename(columns= {"GDP per capita": "Economy (GDP per Capita)"})

happy18_df

happy19_df = happy18_df.rename(columns= {"GDP per capita": "Economy (GDP per Capita)"})

happy19_df


#Health (Life Expectancy)

happy18_df = happy18_df.rename(columns= {"Healthy life expectancy": "Health (Life Expectancy)"})

happy18_df

happy19_df = happy18_df.rename(columns= {"Healthy life expectancy": "Health (Life Expectancy)"})

happy19_df


#Freedom

happy18_df = happy18_df.rename(columns= {"Freedom to make life choices": "Freedom"})

happy18_df

happy19_df = happy18_df.rename(columns= {"Freedom to make life choices": "Freedom"})

happy19_df


#Trust (Government Corruption)

happy18_df = happy18_df.rename(columns= {"Perceptions of corruption": "Trust (Government Corruption)"})

happy18_df

happy19_df = happy18_df.rename(columns= {"Perceptions of corruption": "Trust (Government Corruption)"})

happy19_df


#Family 

happy18_df = happy18_df.rename(columns= {"Social support": "Family"})

happy18_df

happy19_df = happy18_df.rename(columns= {"Social support": "Family"})

happy19_df


#Happiness Score 

happy18_df = happy18_df.rename(columns= {"Score": "Happiness Score"})

happy18_df

happy19_df = happy18_df.rename(columns= {"Score": "Happiness Score"})

happy15_df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 153                   0.42864  0.59201                        0.55191
# 154                   0.31910  0.48450                        0.08010
# 155                   0.72193  0.15684                        0.18906
# 156                   0.22396  0.11850                        0.10062
# 157                   0.28443  0.36453                        0.10731
#
#      Generosity  Dystopia Residual
# 0       0.29678            2.51738
# 1       0.43630            2.70201
# 2       0.34139            2.49204
# 3       0.34699            2.46531
# 4       0.45811            2.45176
# ..          ...                ...
# 153     0.22628            0.67042
# 154     0.18260            1.63328
# 155     0.47179            0.32858
# 156     0.19727            1.83302
# 157     0.16681            1.56726
#
# [158 rows x 12 columns]

# %%
"""
renaming of year 2017
base label: 2015
"""

happy17_df = happy17_df.rename(columns = {"Happiness.Rank": "Happiness Rank"})

happy17_df = happy17_df.rename(columns = {"Happiness.Score": "Happiness Score"})

happy17_df = happy17_df.rename(columns = {"Economy..GDP.per.Capita.": "Economy (GDP per Capita)"})

happy17_df = happy17_df.rename(columns = {"Health..Life.Expectancy.": "Health (Life Expectancy)"})

happy17_df = happy17_df.rename(columns = {"Trust..Government.Corruption.": "Trust (Government Corruption)"})

happy17_df = happy17_df.rename(columns = {"Dystopia.Residual": "Dystopia Residual"})
 

happy17_df = happy17_df.drop(columns = "Whisker.high") 

happy17_df = happy17_df.drop(columns = "Whisker.low")

happy17_df
# Out:
#                       Country  Happiness Rank  Happiness Score  \
# 0                      Norway               1            7.537
# 1                     Denmark               2            7.522
# 2                     Iceland               3            7.504
# 3                 Switzerland               4            7.494
# 4                     Finland               5            7.469
# ..                        ...             ...              ...
# 150                    Rwanda             151            3.471
# 151                     Syria             152            3.462
# 152                  Tanzania             153            3.349
# 153                   Burundi             154            2.905
# 154  Central African Republic             155            2.693
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                    1.616463  1.533524                  0.796667  0.635423
# 1                    1.482383  1.551122                  0.792566  0.626007
# 2                    1.480633  1.610574                  0.833552  0.627163
# 3                    1.564980  1.516912                  0.858131  0.620071
# 4                    1.443572  1.540247                  0.809158  0.617951
# ..                        ...       ...                       ...       ...
# 150                  0.368746  0.945707                  0.326425  0.581844
# 151                  0.777153  0.396103                  0.500533  0.081539
# 152                  0.511136  1.041990                  0.364509  0.390018
# 153                  0.091623  0.629794                  0.151611  0.059901
# 154                  0.000000  0.000000                  0.018773  0.270842
#
#      Generosity  Trust (Government Corruption)  Dystopia Residual
# 0      0.362012                       0.315964           2.277027
# 1      0.355280                       0.400770           2.313707
# 2      0.475540                       0.153527           2.322715
# 3      0.290549                       0.367007           2.276716
# 4      0.245483                       0.382612           2.430182
# ..          ...                            ...                ...
# 150    0.252756                       0.455220           0.540061
# 151    0.493664                       0.151347           1.061574
# 152    0.354256                       0.066035           0.621130
# 153    0.204435                       0.084148           1.683024
# 154    0.280876                       0.056565           2.066005
#
# [155 rows x 10 columns]

# %%
#insert year column at first position (index 0)

#2015
happy15_df.insert(0, "Year",value = "2015")


#2016
happy16_df.insert(0, "Year",value = "2016")


#2017
happy17_df.insert(0, "Year",value = "2017")


#2018
happy18_df.insert(0, "Year",value = "2018")

#2019
happy19_df.insert(0, "Year",value = "2019")

#check if it worked
happy18_df.head()
# Out:
#    Year  Happiness Rank      Country  Happiness Score  \
# 0  2018               1      Finland            7.632
# 1  2018               2       Norway            7.594
# 2  2018               3      Denmark            7.555
# 3  2018               4      Iceland            7.495
# 4  2018               5  Switzerland            7.487
#
#    Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 0                     1.305   1.592                     0.874    0.681
# 1                     1.456   1.582                     0.861    0.686
# 2                     1.351   1.590                     0.868    0.683
# 3                     1.343   1.644                     0.914    0.677
# 4                     1.420   1.549                     0.927    0.660
#
#    Generosity  Trust (Government Corruption)
# 0       0.202                          0.393
# 1       0.286                          0.340
# 2       0.284                          0.408
# 3       0.353                          0.138
# 4       0.256                          0.357

# %% [markdown]
# ___

# %% [markdown]
# # Preperation for cleaning

# %%
#creating empty dict 
region_dict ={}

#filling with values from DataFame happy15_df 

#index to have each row with both data, region and country 
region_dict = happy15_df [["Country","Region"]].to_dict("index")



[(key, value) for key, value in region_dict.items()]
# Out:
# [(0, {'Country': 'Switzerland', 'Region': 'Western Europe'}),
#  (1, {'Country': 'Iceland', 'Region': 'Western Europe'}),
#  (2, {'Country': 'Denmark', 'Region': 'Western Europe'}),
#  (3, {'Country': 'Norway', 'Region': 'Western Europe'}),
#  (4, {'Country': 'Canada', 'Region': 'North America'}),
#  (5, {'Country': 'Finland', 'Region': 'Western Europe'}),
#  (6, {'Country': 'Netherlands', 'Region': 'Western Europe'}),
#  (7, {'Country': 'Sweden', 'Region': 'Western Europe'}),
#  (8, {'Country': 'New Zealand', 'Region': 'Australia and New Zealand'}),
#  (9, {'Country': 'Australia', 'Region': 'Australia and New Zealand'}),
#  (10, {'Country': 'Israel', 'Region': 'Middle East and Northern Africa'}),
#  (11, {'Country': 'Costa Rica', 'Region': 'Latin America and Caribbean'}),
#  (12, {'Country': 'Austria', 'Region': 'Western Europe'}),
#  (13, {'Country': 'Mexico', 'Region': 'Latin America and Caribbean'}),
#  (14, {'Country': 'United States', 'Region': 'North America'}),
#  (15, {'Country': 'Brazil', 'Region': 'Latin America and Caribbean'}),
#  (16, {'Country': 'Luxembourg', 'Region': 'Western Europe'}),
#  (17, {'Country': 'Ireland', 'Region': 'Western Europe'}),
#  (18, {'Country': 'Belgium', 'Region': 'Western Europe'}),
#  (19,
#   {'Country': 'United Arab Emirates',
#    'Region': 'Middle East and Northern Africa'}),
#  (20, {'Country': 'United Kingdom', 'Region': 'Western Europe'}),
#  (21, {'Country': 'Oman', 'Region': 'Middle East and Northern Africa'}),
#  (22, {'Country': 'Venezuela', 'Region': 'Latin America and Caribbean'}),
#  (23, {'Country': 'Singapore', 'Region': 'Southeastern Asia'}),
#  (24, {'Country': 'Panama', 'Region': 'Latin America and Caribbean'}),
#  (25, {'Country': 'Germany', 'Region': 'Western Europe'}),
#  (26, {'Country': 'Chile', 'Region': 'Latin America and Caribbean'}),
#  (27, {'Country': 'Qatar', 'Region': 'Middle East and Northern Africa'}),
#  (28, {'Country': 'France', 'Region': 'Western Europe'}),
#  (29, {'Country': 'Argentina', 'Region': 'Latin America and Caribbean'}),
#  (30, {'Country': 'Czech Republic', 'Region': 'Central and Eastern Europe'}),
#  (31, {'Country': 'Uruguay', 'Region': 'Latin America and Caribbean'}),
#  (32, {'Country': 'Colombia', 'Region': 'Latin America and Caribbean'}),
#  (33, {'Country': 'Thailand', 'Region': 'Southeastern Asia'}),
#  (34,
#   {'Country': 'Saudi Arabia', 'Region': 'Middle East and Northern Africa'}),
#  (35, {'Country': 'Spain', 'Region': 'Western Europe'}),
#  (36, {'Country': 'Malta', 'Region': 'Western Europe'}),
#  (37, {'Country': 'Taiwan', 'Region': 'Eastern Asia'}),
#  (38, {'Country': 'Kuwait', 'Region': 'Middle East and Northern Africa'}),
#  (39, {'Country': 'Suriname', 'Region': 'Latin America and Caribbean'}),
#  (40,
#   {'Country': 'Trinidad and Tobago', 'Region': 'Latin America and Caribbean'}),
#  (41, {'Country': 'El Salvador', 'Region': 'Latin America and Caribbean'}),
#  (42, {'Country': 'Guatemala', 'Region': 'Latin America and Caribbean'}),
#  (43, {'Country': 'Uzbekistan', 'Region': 'Central and Eastern Europe'}),
#  (44, {'Country': 'Slovakia', 'Region': 'Central and Eastern Europe'}),
#  (45, {'Country': 'Japan', 'Region': 'Eastern Asia'}),
#  (46, {'Country': 'South Korea', 'Region': 'Eastern Asia'}),
#  (47, {'Country': 'Ecuador', 'Region': 'Latin America and Caribbean'}),
#  (48, {'Country': 'Bahrain', 'Region': 'Middle East and Northern Africa'}),
#  (49, {'Country': 'Italy', 'Region': 'Western Europe'}),
#  (50, {'Country': 'Bolivia', 'Region': 'Latin America and Caribbean'}),
#  (51, {'Country': 'Moldova', 'Region': 'Central and Eastern Europe'}),
#  (52, {'Country': 'Paraguay', 'Region': 'Latin America and Caribbean'}),
#  (53, {'Country': 'Kazakhstan', 'Region': 'Central and Eastern Europe'}),
#  (54, {'Country': 'Slovenia', 'Region': 'Central and Eastern Europe'}),
#  (55, {'Country': 'Lithuania', 'Region': 'Central and Eastern Europe'}),
#  (56, {'Country': 'Nicaragua', 'Region': 'Latin America and Caribbean'}),
#  (57, {'Country': 'Peru', 'Region': 'Latin America and Caribbean'}),
#  (58, {'Country': 'Belarus', 'Region': 'Central and Eastern Europe'}),
#  (59, {'Country': 'Poland', 'Region': 'Central and Eastern Europe'}),
#  (60, {'Country': 'Malaysia', 'Region': 'Southeastern Asia'}),
#  (61, {'Country': 'Croatia', 'Region': 'Central and Eastern Europe'}),
#  (62, {'Country': 'Libya', 'Region': 'Middle East and Northern Africa'}),
#  (63, {'Country': 'Russia', 'Region': 'Central and Eastern Europe'}),
#  (64, {'Country': 'Jamaica', 'Region': 'Latin America and Caribbean'}),
#  (65, {'Country': 'North Cyprus', 'Region': 'Western Europe'}),
#  (66, {'Country': 'Cyprus', 'Region': 'Western Europe'}),
#  (67, {'Country': 'Algeria', 'Region': 'Middle East and Northern Africa'}),
#  (68, {'Country': 'Kosovo', 'Region': 'Central and Eastern Europe'}),
#  (69, {'Country': 'Turkmenistan', 'Region': 'Central and Eastern Europe'}),
#  (70, {'Country': 'Mauritius', 'Region': 'Sub-Saharan Africa'}),
#  (71, {'Country': 'Hong Kong', 'Region': 'Eastern Asia'}),
#  (72, {'Country': 'Estonia', 'Region': 'Central and Eastern Europe'}),
#  (73, {'Country': 'Indonesia', 'Region': 'Southeastern Asia'}),
#  (74, {'Country': 'Vietnam', 'Region': 'Southeastern Asia'}),
#  (75, {'Country': 'Turkey', 'Region': 'Middle East and Northern Africa'}),
#  (76, {'Country': 'Kyrgyzstan', 'Region': 'Central and Eastern Europe'}),
#  (77, {'Country': 'Nigeria', 'Region': 'Sub-Saharan Africa'}),
#  (78, {'Country': 'Bhutan', 'Region': 'Southern Asia'}),
#  (79, {'Country': 'Azerbaijan', 'Region': 'Central and Eastern Europe'}),
#  (80, {'Country': 'Pakistan', 'Region': 'Southern Asia'}),
#  (81, {'Country': 'Jordan', 'Region': 'Middle East and Northern Africa'}),
#  (82, {'Country': 'Montenegro', 'Region': 'Central and Eastern Europe'}),
#  (83, {'Country': 'China', 'Region': 'Eastern Asia'}),
#  (84, {'Country': 'Zambia', 'Region': 'Sub-Saharan Africa'}),
#  (85, {'Country': 'Romania', 'Region': 'Central and Eastern Europe'}),
#  (86, {'Country': 'Serbia', 'Region': 'Central and Eastern Europe'}),
#  (87, {'Country': 'Portugal', 'Region': 'Western Europe'}),
#  (88, {'Country': 'Latvia', 'Region': 'Central and Eastern Europe'}),
#  (89, {'Country': 'Philippines', 'Region': 'Southeastern Asia'}),
#  (90, {'Country': 'Somaliland region', 'Region': 'Sub-Saharan Africa'}),
#  (91, {'Country': 'Morocco', 'Region': 'Middle East and Northern Africa'}),
#  (92, {'Country': 'Macedonia', 'Region': 'Central and Eastern Europe'}),
#  (93, {'Country': 'Mozambique', 'Region': 'Sub-Saharan Africa'}),
#  (94, {'Country': 'Albania', 'Region': 'Central and Eastern Europe'}),
#  (95,
#   {'Country': 'Bosnia and Herzegovina',
#    'Region': 'Central and Eastern Europe'}),
#  (96, {'Country': 'Lesotho', 'Region': 'Sub-Saharan Africa'}),
#  (97,
#   {'Country': 'Dominican Republic', 'Region': 'Latin America and Caribbean'}),
#  (98, {'Country': 'Laos', 'Region': 'Southeastern Asia'}),
#  (99, {'Country': 'Mongolia', 'Region': 'Eastern Asia'}),
#  (100, {'Country': 'Swaziland', 'Region': 'Sub-Saharan Africa'}),
#  (101, {'Country': 'Greece', 'Region': 'Western Europe'}),
#  (102, {'Country': 'Lebanon', 'Region': 'Middle East and Northern Africa'}),
#  (103, {'Country': 'Hungary', 'Region': 'Central and Eastern Europe'}),
#  (104, {'Country': 'Honduras', 'Region': 'Latin America and Caribbean'}),
#  (105, {'Country': 'Tajikistan', 'Region': 'Central and Eastern Europe'}),
#  (106, {'Country': 'Tunisia', 'Region': 'Middle East and Northern Africa'}),
#  (107,
#   {'Country': 'Palestinian Territories',
#    'Region': 'Middle East and Northern Africa'}),
#  (108, {'Country': 'Bangladesh', 'Region': 'Southern Asia'}),
#  (109, {'Country': 'Iran', 'Region': 'Middle East and Northern Africa'}),
#  (110, {'Country': 'Ukraine', 'Region': 'Central and Eastern Europe'}),
#  (111, {'Country': 'Iraq', 'Region': 'Middle East and Northern Africa'}),
#  (112, {'Country': 'South Africa', 'Region': 'Sub-Saharan Africa'}),
#  (113, {'Country': 'Ghana', 'Region': 'Sub-Saharan Africa'}),
#  (114, {'Country': 'Zimbabwe', 'Region': 'Sub-Saharan Africa'}),
#  (115, {'Country': 'Liberia', 'Region': 'Sub-Saharan Africa'}),
#  (116, {'Country': 'India', 'Region': 'Southern Asia'}),
#  (117, {'Country': 'Sudan', 'Region': 'Sub-Saharan Africa'}),
#  (118, {'Country': 'Haiti', 'Region': 'Latin America and Caribbean'}),
#  (119, {'Country': 'Congo (Kinshasa)', 'Region': 'Sub-Saharan Africa'}),
#  (120, {'Country': 'Nepal', 'Region': 'Southern Asia'}),
#  (121, {'Country': 'Ethiopia', 'Region': 'Sub-Saharan Africa'}),
#  (122, {'Country': 'Sierra Leone', 'Region': 'Sub-Saharan Africa'}),
#  (123, {'Country': 'Mauritania', 'Region': 'Sub-Saharan Africa'}),
#  (124, {'Country': 'Kenya', 'Region': 'Sub-Saharan Africa'}),
#  (125, {'Country': 'Djibouti', 'Region': 'Sub-Saharan Africa'}),
#  (126, {'Country': 'Armenia', 'Region': 'Central and Eastern Europe'}),
#  (127, {'Country': 'Botswana', 'Region': 'Sub-Saharan Africa'}),
#  (128, {'Country': 'Myanmar', 'Region': 'Southeastern Asia'}),
#  (129, {'Country': 'Georgia', 'Region': 'Central and Eastern Europe'}),
#  (130, {'Country': 'Malawi', 'Region': 'Sub-Saharan Africa'}),
#  (131, {'Country': 'Sri Lanka', 'Region': 'Southern Asia'}),
#  (132, {'Country': 'Cameroon', 'Region': 'Sub-Saharan Africa'}),
#  (133, {'Country': 'Bulgaria', 'Region': 'Central and Eastern Europe'}),
#  (134, {'Country': 'Egypt', 'Region': 'Middle East and Northern Africa'}),
#  (135, {'Country': 'Yemen', 'Region': 'Middle East and Northern Africa'}),
#  (136, {'Country': 'Angola', 'Region': 'Sub-Saharan Africa'}),
#  (137, {'Country': 'Mali', 'Region': 'Sub-Saharan Africa'}),
#  (138, {'Country': 'Congo (Brazzaville)', 'Region': 'Sub-Saharan Africa'}),
#  (139, {'Country': 'Comoros', 'Region': 'Sub-Saharan Africa'}),
#  (140, {'Country': 'Uganda', 'Region': 'Sub-Saharan Africa'}),
#  (141, {'Country': 'Senegal', 'Region': 'Sub-Saharan Africa'}),
#  (142, {'Country': 'Gabon', 'Region': 'Sub-Saharan Africa'}),
#  (143, {'Country': 'Niger', 'Region': 'Sub-Saharan Africa'}),
#  (144, {'Country': 'Cambodia', 'Region': 'Southeastern Asia'}),
#  (145, {'Country': 'Tanzania', 'Region': 'Sub-Saharan Africa'}),
#  (146, {'Country': 'Madagascar', 'Region': 'Sub-Saharan Africa'}),
#  (147,
#   {'Country': 'Central African Republic', 'Region': 'Sub-Saharan Africa'}),
#  (148, {'Country': 'Chad', 'Region': 'Sub-Saharan Africa'}),
#  (149, {'Country': 'Guinea', 'Region': 'Sub-Saharan Africa'}),
#  (150, {'Country': 'Ivory Coast', 'Region': 'Sub-Saharan Africa'}),
#  (151, {'Country': 'Burkina Faso', 'Region': 'Sub-Saharan Africa'}),
#  (152, {'Country': 'Afghanistan', 'Region': 'Southern Asia'}),
#  (153, {'Country': 'Rwanda', 'Region': 'Sub-Saharan Africa'}),
#  (154, {'Country': 'Benin', 'Region': 'Sub-Saharan Africa'}),
#  (155, {'Country': 'Syria', 'Region': 'Middle East and Northern Africa'}),
#  (156, {'Country': 'Burundi', 'Region': 'Sub-Saharan Africa'}),
#  (157, {'Country': 'Togo', 'Region': 'Sub-Saharan Africa'})]

# %% [markdown]
# # Merging the datasets

# %%
#concatenating objects 

#defintion of all the sets we want to bring together
frames = [happy15_df, happy16_df,  happy17_df, happy18_df, happy19_df]

happiness = pd.concat (frames)
happiness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 782 entries, 0 to 155
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Year                           782 non-null    object
#  1   Country                        782 non-null    object
#  2   Region                         315 non-null    object
#  3   Happiness Rank                 782 non-null    int64
#  4   Happiness Score                782 non-null    float64
#  5   Standard Error                 158 non-null    float64
#  6   Economy (GDP per Capita)       782 non-null    float64
#  7   Family                         782 non-null    float64
#  8   Health (Life Expectancy)       782 non-null    float64
#  9   Freedom                        782 non-null    float64
#  10  Trust (Government Corruption)  780 non-null    float64
#  11  Generosity                     782 non-null    float64
#  12  Dystopia Residual              470 non-null    float64
#  13  Lower Confidence Interval      157 non-null    float64
#  14  Upper Confidence Interval      157 non-null    float64
# dtypes: float64(11), int64(1), object(3)
# memory usage: 97.8+ KB

# %% [markdown]
#  Delete unnessesary columns:

# %%
happiness = happiness.drop (["Lower Confidence Interval","Dystopia Residual", "Upper Confidence Interval", "Standard Error"], axis = 1)
happiness.head()
# Out:
#    Year      Country          Region  Happiness Rank  Happiness Score  \
# 0  2015  Switzerland  Western Europe               1            7.587
# 1  2015      Iceland  Western Europe               2            7.561
# 2  2015      Denmark  Western Europe               3            7.527
# 3  2015       Norway  Western Europe               4            7.522
# 4  2015       Canada   North America               5            7.427
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity
# 0                        0.41978     0.29678
# 1                        0.14145     0.43630
# 2                        0.48357     0.34139
# 3                        0.36503     0.34699
# 4                        0.32957     0.45811

# %%
happiness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 782 entries, 0 to 155
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Year                           782 non-null    object
#  1   Country                        782 non-null    object
#  2   Region                         315 non-null    object
#  3   Happiness Rank                 782 non-null    int64
#  4   Happiness Score                782 non-null    float64
#  5   Economy (GDP per Capita)       782 non-null    float64
#  6   Family                         782 non-null    float64
#  7   Health (Life Expectancy)       782 non-null    float64
#  8   Freedom                        782 non-null    float64
#  9   Trust (Government Corruption)  780 non-null    float64
#  10  Generosity                     782 non-null    float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# Note: year is a object type and we have to convert it

# %%
#conversion of type str to float64 (alternatively: int)
happiness ["Year"] = happiness ["Year"].astype(int)

#convert object data to category data 
happiness ["Country"] = happiness ["Country"].astype("category")
#happiness ["Region"] = happiness ["Region"].astype("category")

happiness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 782 entries, 0 to 155
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Year                           782 non-null    int32
#  1   Country                        782 non-null    category
#  2   Region                         776 non-null    category
#  3   Happiness Rank                 782 non-null    int64
#  4   Happiness Score                782 non-null    float64
#  5   Economy (GDP per Capita)       782 non-null    float64
#  6   Family                         782 non-null    float64
#  7   Health (Life Expectancy)       782 non-null    float64
#  8   Freedom                        782 non-null    float64
#  9   Trust (Government Corruption)  780 non-null    float64
#  10  Generosity                     782 non-null    float64
# dtypes: category(2), float64(7), int32(1), int64(1)
# memory usage: 66.1 KB

# %% [markdown]
# a more visual way of presenting the null values:

# %%
#yellow is what is missig and we see that is substential 
import seaborn as sns

plt.figure (figsize=(10,7))

sns.heatmap(happiness.isnull(),yticklabels=False, cbar = False, cmap = "plasma")
plt.xlabel(xlabel = "variable names", rotation= 0, fontsize= 20)
plt.ylabel (ylabel= "missing data", fontsize = 20)
plt.title (label = "missing data per variable",  fontsize = 25)
plt.show()

# %% [markdown]
# prior we made a dictionary with the regional data categories that we not fil in

# %%
    
plt.figure (figsize=(10,7))

sns.heatmap(happiness.isnull(),yticklabels=False, cbar = False, cmap = "plasma")
plt.xlabel(xlabel = "variable names", rotation= 0, fontsize= 20)
plt.ylabel (ylabel= "missing data", fontsize = 20)
plt.title (label = "missing data per variable",  fontsize = 25)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 782 entries, 0 to 155
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Year                           782 non-null    int32
#  1   Country                        782 non-null    category
#  2   Region                         782 non-null    category
#  3   Happiness Rank                 782 non-null    int64
#  4   Happiness Score                782 non-null    float64
#  5   Economy (GDP per Capita)       782 non-null    float64
#  6   Family                         782 non-null    float64
#  7   Health (Life Expectancy)       782 non-null    float64
#  8   Freedom                        782 non-null    float64
#  9   Trust (Government Corruption)  780 non-null    float64
#  10  Generosity                     782 non-null    float64
# dtypes: category(2), float64(7), int32(1), int64(1)
# memory usage: 82.2 KB

# %% [markdown]
# we still have a few missing variables

# %%
happiness [happiness["Region"].isna()]

#we see that we only have 6 missing values and will therefore, assign the regions manually
# Out:
#     Year                   Country Region  Happiness Rank  Happiness Score  \
# 32  2017  Taiwan Province of China    NaN              33            6.422
# 70  2017   Hong Kong S.A.R., China    NaN              71            5.472
# 37  2018         Trinidad & Tobago    NaN              38            6.192
# 57  2018           Northern Cyprus    NaN              58            5.835
# 37  2019         Trinidad & Tobago    NaN              38            6.192
# 57  2019           Northern Cyprus    NaN              58            5.835
#
#     Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 32                  1.433627  1.384565                  0.793984  0.361467
# 70                  1.551675  1.262791                  0.943062  0.490969
# 37                  1.223000  1.492000                  0.564000  0.575000
# 57                  1.229000  1.211000                  0.909000  0.495000
# 37                  1.223000  1.492000                  0.564000  0.575000
# 57                  1.229000  1.211000                  0.909000  0.495000
#
#     Trust (Government Corruption)  Generosity
# 32                       0.063829    0.258360
# 70                       0.293934    0.374466
# 37                       0.019000    0.171000
# 57                       0.154000    0.179000
# 37                       0.019000    0.171000
# 57                       0.154000    0.179000

# %%
happiness.loc[[32,70], "Region"] =  "Eastern Asia"
happiness [happiness["Region"].isna()]
# Out:
# Empty DataFrame
# Columns: [Year, Country, Region, Happiness Rank, Happiness Score, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity]
# Index: []

# %%
#lets look for the missing regions in the rest of the data 
happiness [happiness.Region == "Latin America and Caribbean"]

#replacing of missing values: 
happiness.loc[[37], "Region"] =  "Latin America and Caribbean"
happiness [happiness["Region"].isna()]
# Out:
# Empty DataFrame
# Columns: [Year, Country, Region, Happiness Rank, Happiness Score, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity]
# Index: []

# %%
#lets look for the missing regions in the rest of the data 
happiness [happiness.Region == "Western Europe"]


#replacing of missing values: 
happiness.loc[[57], "Region"] =  "Western Europe"
happiness [happiness["Region"].isna()]


try:
    for country in happiness.Country.unique():
        happiness.loc[happiness['Country']==str(country),
                              'Region']=happiness[happiness['Country']==str(country)].Region.mode()[0]
except IndexError:
    pass

happiness.info()
# Out:
# Empty DataFrame
# Columns: [Year, Country, Region, Happiness Rank, Happiness Score, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity]
# Index: []

# %%
plt.figure (figsize=(10,7))

sns.heatmap(happiness.isnull(),yticklabels=False, cbar = False, cmap = "plasma")
plt.xlabel(xlabel = "variable names", rotation= 0, fontsize= 20)
plt.ylabel (ylabel= "missing data", fontsize = 20)
plt.title (label = "missing data per variable",  fontsize = 25)
plt.show()

# %%
#finding the missing trust variable 
happiness [happiness["Trust (Government Corruption)"].isna()]
# Out:
#     Year               Country                           Region  \
# 19  2018  United Arab Emirates  Middle East and Northern Africa
# 19  2019  United Arab Emirates  Middle East and Northern Africa
#
#     Happiness Rank  Happiness Score  Economy (GDP per Capita)  Family  \
# 19              20            6.774                     2.096   0.776
# 19              20            6.774                     2.096   0.776
#
#     Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 19                      0.67    0.284                            NaN
# 19                      0.67    0.284                            NaN
#
#     Generosity
# 19       0.186
# 19       0.186

# %%
round (happiness.describe(), 3)
# Out:
#            Year  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# count   782.000         782.000          782.000                   782.000
# mean   2016.994          78.698            5.373                     0.913
# std       1.417          45.182            1.129                     0.406
# min    2015.000           1.000            2.693                     0.000
# 25%    2016.000          40.000            4.471                     0.607
# 50%    2017.000          79.000            5.322                     0.978
# 75%    2018.000         118.000            6.173                     1.229
# max    2019.000         158.000            7.632                     2.096
#
#         Family  Health (Life Expectancy)  Freedom  \
# count  782.000                   782.000  782.000
# mean     1.079                     0.587    0.423
# std      0.330                     0.243    0.157
# min      0.000                     0.000    0.000
# 25%      0.870                     0.406    0.318
# 50%      1.125                     0.635    0.445
# 75%      1.330                     0.774    0.545
# max      1.644                     1.030    0.724
#
#        Trust (Government Corruption)  Generosity
# count                        780.000     782.000
# mean                           0.126       0.218
# std                            0.106       0.123
# min                            0.000       0.000
# 25%                            0.054       0.130
# 50%                            0.092       0.201
# 75%                            0.155       0.281
# max                            0.552       0.838

# %% [markdown]
# desision for value to replace NaN:
#
#     - We see that the mean and median are not to close with one another
#     - just using one of the values whould ignore the country specific sources and also the development over the time
#     - replacing it with 0 would be completely disadvisably, as even with the std in account the value is more than likely not 0
#     - because of the above mentioned we go back to the inital year data and replace the values manually

# %%
#we find out a few variables to decisde with what we want to replace the missing values

#average of United Arab Emirates

year_trust = happiness.loc [:,"Trust (Government Corruption)":]


mean = year_trust.mean (axis=1)
print ("Mean","\n",mean[19])

median = year_trust.median (axis = 1)
print ("\n","Median","\n",median[19])


#so ahappiness.loc[[57], "Region"] =  "Western Europe"
happiness [happiness["Trust (Government Corruption)"].isna()]
# Out:
# Mean
#  19    0.325055
# 19    0.314500
# 19    0.204475
# 19    0.186000
# 19    0.186000
# dtype: float64
#
#  Median
#  19    0.325055
# 19    0.314500
# 19    0.204475
# 19    0.186000
# 19    0.186000
# dtype: float64
#     Year               Country                           Region  \
# 19  2018  United Arab Emirates  Middle East and Northern Africa
# 19  2019  United Arab Emirates  Middle East and Northern Africa
#
#     Happiness Rank  Happiness Score  Economy (GDP per Capita)  Family  \
# 19              20            6.774                     2.096   0.776
# 19              20            6.774                     2.096   0.776
#
#     Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 19                      0.67    0.284                            NaN
# 19                      0.67    0.284                            NaN
#
#     Generosity
# 19       0.186
# 19       0.186

# %%
# Replacing the is.na values 

happiness.loc[[19], "Trust (Government Corruption)"] =  0.18600

#we check if we have deleted all the null vales (worked!)
happiness [happiness["Trust (Government Corruption)"].isna()]
# Out:
# Empty DataFrame
# Columns: [Year, Country, Region, Happiness Rank, Happiness Score, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity]
# Index: []

# %%
#one last time (hopefully)
plt.figure (figsize=(10,7))

sns.heatmap(happiness.isnull(),yticklabels=False, cbar = False, cmap = "plasma")
plt.xlabel(xlabel = "variable names", rotation= 0, fontsize= 20)
plt.ylabel (ylabel= "missing data", fontsize = 20)
plt.title (label = "missing data per variable",  fontsize = 25)
plt.show()


# save the combined data in one file
happiness.to_csv('Data_combined/happiness_info.csv', index=False)
